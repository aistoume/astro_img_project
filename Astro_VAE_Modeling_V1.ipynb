# %% [markdown]
# # Project Exoplane Background Removal

# %% [markdown]
# ### Initialization

# %%
# Loading libs
from astropy.io import fits #need to install the "astropy" package

# system lib
import numpy as np
import os
import cv2
import copy
import re
from glob import glob
import imageio
import subprocess
import datetime
import collections
import random
import time
import shutil

from astro_vae_package import astro_plot
from astro_vae_package import utils

# machine learning lib
import tensorflow as tf
from tensorflow.keras import layers
from sklearn.cluster import KMeans
from sklearn.preprocessing import normalize
from IPython import display

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, random_split
from torchvision import transforms
from torch.utils.data import Dataset

# plot lib
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.image as mpimg
import matplotlib.colors as colors
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.colors import LogNorm
from matplotlib.backends.backend_pdf import PdfPages
import PIL
from PIL import Image
from scipy.ndimage import zoom

# %%
print(torch.cuda.is_available())
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# True
# cuda

# %% [markdown]
# ### Load fits no disk which is picked by Fang's algorithm.

# %%
# Ring region, where there is only the control ring (i.e., no disk signal) when mask = 1
mask_ring = fits.getdata('assets\\mask_ring.fits')
mask_ring = utils.crop_central_squared_image(mask_ring)

# Regions to plot, ignore the mask = 0 regions
mask_plot = fits.getdata('assets\\mask_plot.fits')
mask_plot = utils.crop_central_squared_image(mask_plot)

# Regions of input, drop data where the mask = 0
mask_input = fits.getdata('assets\\mask_input.fits')
mask_input = utils.crop_central_squared_image(mask_input)

# Regions to impute, ignore the mask = 0 regions
mask_impute = fits.getdata('assets\\mask_impute.fits')
mask_impute = utils.crop_central_squared_image(mask_impute)

# %%
# Masked target image

fig = plt.figure(figsize = (6, 4))
fig, axs = plt.subplots(1, 3)
astro_plot.subplot_log_image(axs[0], mask_plot, vmax=1)
astro_plot.subplot_log_image(axs[1], mask_impute, vmax=1)
astro_plot.subplot_log_image(axs[2], mask_input, vmax=1)

# %%
dataset_all_path = 'POLARIS_Exoplanet_Data\\dataset_all'
dataset_ref_path = 'POLARIS_Exoplanet_Data\\dataset_reference'
vae_raw_imgs = []
vae_input_imgs = []
vae_target_imgs = []
vae_log_raw_imgs = []
vae_log_input_imgs = []
vae_log_target_imgs = []
vae_norm_raw_imgs = []
vae_norm_input_imgs = []
vae_norm_target_imgs = []
file_num = 0
total = 0

debug_mode = True
for root, dirs, files in os.walk(dataset_ref_path):
    for file in files:
        if re.match(r'^[^.].*_frames.fits$', file, False):
            imgs = fits.getdata(os.path.join(root, file))
            file_num += 1
            if debug_mode:
                img = imgs[0]
                img = utils.crop_central_squared_image(img)
                log_img = utils.get_log_img(img)
                norm_img = utils.normalize_img(log_img)
                vae_raw_imgs.append(img)
                vae_input_imgs.append(img * mask_input)
                vae_target_imgs.append(img * mask_impute)
                vae_log_raw_imgs.append(log_img)
                vae_log_input_imgs.append(log_img * mask_input)
                vae_log_target_imgs.append(log_img * mask_impute)
                vae_norm_raw_imgs.append(norm_img)
                vae_norm_input_imgs.append(norm_img * mask_input)
                vae_norm_target_imgs.append(norm_img * mask_impute)
                total += 1
            else:
                count = 0
                for img in imgs:
                    if count > 3:
                        continue
                    img = crop_central_squared_image(img)
                    log_img = get_log_img(img)
                    norm_img = normalize_img(log_img)
                    vae_raw_imgs.append(img)
                    vae_input_imgs.append(img * mask_input)
                    vae_target_imgs.append(img * mask_impute)
                    vae_log_raw_imgs.append(log_img)
                    vae_log_input_imgs.append(log_img * mask_input)
                    vae_log_target_imgs.append(log_img * mask_impute)
                    vae_norm_raw_imgs.append(norm_img)
                    vae_norm_input_imgs.append(norm_img * mask_input)
                    vae_norm_target_imgs.append(norm_img * mask_impute)
                    total += 1
                    count += 1

# %%
x = vae_norm_target_imgs[0]
plt.hist(x.reshape(-1), bins=50)
# Out:
# (array([5.1000e+01, 6.2000e+01, 8.0000e+01, 1.0400e+02, 1.3000e+02,
#         1.3300e+02, 2.1700e+02, 2.4000e+02, 3.4300e+02, 4.2200e+02,
#         5.8000e+02, 6.5300e+02, 8.6400e+02, 1.0980e+03, 1.2750e+03,
#         1.5730e+03, 1.8450e+03, 2.0910e+03, 2.1750e+03, 2.7462e+04,
#         2.3330e+03, 2.4560e+03, 2.7030e+03, 2.7530e+03, 2.4040e+03,
#         1.8280e+03, 1.4160e+03, 1.2680e+03, 1.0330e+03, 1.0000e+03,
#         9.1300e+02, 7.5300e+02, 6.0300e+02, 4.9200e+02, 3.4500e+02,
#         2.9600e+02, 2.5000e+02, 2.2500e+02, 1.9500e+02, 1.5100e+02,
#         1.4500e+02, 1.4400e+02, 1.2900e+02, 1.0800e+02, 6.7000e+01,
#         5.6000e+01, 3.7000e+01, 2.3000e+01, 6.0000e+00, 6.0000e+00]),
#  array([-2.29305935, -2.17270391, -2.05234848, -1.93199305, -1.81163761,
#         -1.69128218, -1.57092674, -1.45057131, -1.33021587, -1.20986044,
#         -1.089505  , -0.96914957, -0.84879414, -0.7284387 , -0.60808327,
#         -0.48772783, -0.3673724 , -0.24701696, -0.12666153, -0.0063061 ,
#          0.11404934,  0.23440477,  0.35476021,  0.47511564,  0.59547108,
#          0.71582651,  0.83618195,  0.95653738,  1.07689281,  1.19724825,
#          1.31760368,  1.43795912,  1.55831455,  1.67866999,  1.79902542,
#          1.91938086,  2.03973629,  2.16009172,  2.28044716,  2.40080259,
#          2.52115803,  2.64151346,  2.7618689 ,  2.88222433,  3.00257977,
#          3.1229352 ,  3.24329063,  3.36364607,  3.4840015 ,  3.60435694,
#          3.72471237]),
#  <BarContainer object of 50 artists>)

# %%
fig = plt.figure(figsize = (6, 6))
fig, axs = plt.subplots(3, 3)
idx = 10
astro_plot.subplot_log_image(axs[0, 0], vae_input_imgs[idx], 1e4)
astro_plot.subplot_log_image(axs[0, 1], vae_target_imgs[idx], 1e4)
astro_plot.subplot_log_image(axs[0, 2], vae_raw_imgs[idx], 1e4)
astro_plot.subplot_linear_image(axs[1, 0], vae_log_input_imgs[idx], 0, 10)
astro_plot.subplot_linear_image(axs[1, 1], vae_log_target_imgs[idx], 0, 10)
astro_plot.subplot_linear_image(axs[1, 2], vae_log_raw_imgs[idx], 0, 10)
astro_plot.subplot_linear_image(axs[2, 0], vae_norm_input_imgs[idx], vmin = 0, vmax = 1)
astro_plot.subplot_linear_image(axs[2, 1], vae_norm_target_imgs[idx], vmin = 0, vmax = 1)
astro_plot.subplot_linear_image(axs[2, 2], vae_norm_raw_imgs[idx], vmin = 0, vmax = 1)

# %% [markdown]
# ### VAE Modeling

# %% [markdown]
# ### Training and Data validation

# %%
# =======================
# Training
# =======================
from astro_vae_package import dataset
from astro_vae_package import vae_model
from astro_vae_package import training

dataset = dataset.CreateTrainingImagesDataset(vae_norm_input_imgs, vae_norm_target_imgs)
val_fraction = 0.1
val_size = int(len(dataset) * val_fraction)
train_size = len(dataset) - val_size
train_dataset, val_dataset = random_split(dataset, [train_size, val_size])

train_loader = DataLoader(train_dataset, batch_size=1, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=1)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
vae = vae_model.AstroConvVae(in_channel=1, latent_dim=16).to(device)
optimizer = torch.optim.Adam(vae.parameters(), lr=1e-4)

loss_hist = training.train_vae(vae, train_loader, val_loader, optimizer, device,
                      epochs=150, kl_max=1e-4, kl_warmup_epochs=20,
                      print_every=5, save_every=10, boundary_weight = 0.8, circle_radius = 80, boundary_width = 5,
                      checkpoint_dir='vae_checkpoints\\VAE_result_fit')
# Out:
# Epoch 5 | Train Total Loss: 2.7537 | Recon Loss: 0.1945 | KL Loss: 68.8278 | KL Weight: 0.0000Pattern Loss: 2.4564
# Epoch 5 | Val Total Loss: 2.2179 | Val Recon Loss: 0.1558 | Val KL Loss: 62.2507| Val Boundary Loss: 0.1093| Val Pattern Loss: 1.9731
# Epoch 10 | Train Total Loss: 2.6546 | Recon Loss: 0.1702 | KL Loss: 60.7793 | KL Weight: 0.0001Pattern Loss: 2.3865
# Epoch 10 | Val Total Loss: 2.1957 | Val Recon Loss: 0.1782 | Val KL Loss: 54.9056| Val Boundary Loss: 0.0923| Val Pattern Loss: 1.9409
# Epoch 15 | Train Total Loss: 2.5802 | Recon Loss: 0.1440 | KL Loss: 58.0365 | KL Weight: 0.0001Pattern Loss: 2.3432
# Epoch 15 | Val Total Loss: 2.1454 | Val Recon Loss: 0.1442 | Val KL Loss: 54.5853| Val Boundary Loss: 0.0902| Val Pattern Loss: 1.9249
# Epoch 20 | Train Total Loss: 2.5331 | Recon Loss: 0.1288 | KL Loss: 56.9935 | KL Weight: 0.0001Pattern Loss: 2.3132
# Epoch 20 | Val Total Loss: 2.1470 | Val Recon Loss: 0.1474 | Val KL Loss: 56.2573| Val Boundary Loss: 0.0957| Val Pattern Loss: 1.9174
# Epoch 25 | Train Total Loss: 2.4968 | Recon Loss: 0.1218 | KL Loss: 57.6330 | KL Weight: 0.0001Pattern Loss: 2.2857
# Epoch 25 | Val Total Loss: 2.1285 | Val Recon Loss: 0.1353 | Val KL Loss: 55.0111| Val Boundary Loss: 0.0925| Val Pattern Loss: 1.9137
# Epoch 30 | Train Total Loss: 2.4484 | Recon Loss: 0.1117 | KL Loss: 58.9931 | KL Weight: 0.0001Pattern Loss: 2.2490
# Epoch 30 | Val Total Loss: 2.1423 | Val Recon Loss: 0.1437 | Val KL Loss: 54.6745| Val Boundary Loss: 0.0883| Val Pattern Loss: 1.9225
# Epoch 35 | Train Total Loss: 2.4165 | Recon Loss: 0.1136 | KL Loss: 60.1370 | KL Weight: 0.0001Pattern Loss: 2.2152
# Epoch 35 | Val Total Loss: 2.1579 | Val Recon Loss: 0.1502 | Val KL Loss: 60.2293| Val Boundary Loss: 0.0898| Val Pattern Loss: 1.9298
# Epoch 40 | Train Total Loss: 2.3697 | Recon Loss: 0.1108 | KL Loss: 61.2378 | KL Weight: 0.0001Pattern Loss: 2.1720
# Epoch 40 | Val Total Loss: 2.1437 | Val Recon Loss: 0.1404 | Val KL Loss: 55.5964| Val Boundary Loss: 0.0868| Val Pattern Loss: 1.9282
# Epoch 45 | Train Total Loss: 2.3132 | Recon Loss: 0.1030 | KL Loss: 63.2668 | KL Weight: 0.0001Pattern Loss: 2.1233
# Epoch 45 | Val Total Loss: 2.1999 | Val Recon Loss: 0.1388 | Val KL Loss: 61.3489| Val Boundary Loss: 0.0902| Val Pattern Loss: 1.9828
# Epoch 50 | Train Total Loss: 2.2561 | Recon Loss: 0.1011 | KL Loss: 65.8408 | KL Weight: 0.0001Pattern Loss: 2.0710
# Epoch 50 | Val Total Loss: 2.1943 | Val Recon Loss: 0.1402 | Val KL Loss: 62.5361| Val Boundary Loss: 0.0930| Val Pattern Loss: 1.9735
# Epoch 55 | Train Total Loss: 2.1880 | Recon Loss: 0.0953 | KL Loss: 66.0869 | KL Weight: 0.0001Pattern Loss: 2.0096
# Epoch 55 | Val Total Loss: 2.2008 | Val Recon Loss: 0.1349 | Val KL Loss: 62.1355| Val Boundary Loss: 0.0909| Val Pattern Loss: 1.9870
# Epoch 60 | Train Total Loss: 2.1597 | Recon Loss: 0.1015 | KL Loss: 68.3580 | KL Weight: 0.0001Pattern Loss: 1.9740
# Epoch 60 | Val Total Loss: 2.1909 | Val Recon Loss: 0.1303 | Val KL Loss: 60.4582| Val Boundary Loss: 0.0906| Val Pattern Loss: 1.9820
# Epoch 65 | Train Total Loss: 2.0974 | Recon Loss: 0.0961 | KL Loss: 67.7004 | KL Weight: 0.0001Pattern Loss: 1.9191
# Epoch 65 | Val Total Loss: 2.2100 | Val Recon Loss: 0.1398 | Val KL Loss: 61.1444| Val Boundary Loss: 0.0940| Val Pattern Loss: 1.9889
# Epoch 70 | Train Total Loss: 2.0567 | Recon Loss: 0.0957 | KL Loss: 66.6577 | KL Weight: 0.0001Pattern Loss: 1.8788
# Epoch 70 | Val Total Loss: 2.2132 | Val Recon Loss: 0.1358 | Val KL Loss: 61.0130| Val Boundary Loss: 0.0897| Val Pattern Loss: 1.9995
# Epoch 75 | Train Total Loss: 2.0114 | Recon Loss: 0.0890 | KL Loss: 68.7808 | KL Weight: 0.0001Pattern Loss: 1.8426
# Epoch 75 | Val Total Loss: 2.1827 | Val Recon Loss: 0.1442 | Val KL Loss: 55.3395| Val Boundary Loss: 0.0954| Val Pattern Loss: 1.9566
# Epoch 80 | Train Total Loss: 1.9722 | Recon Loss: 0.0882 | KL Loss: 69.5264 | KL Weight: 0.0001Pattern Loss: 1.8046
# Epoch 80 | Val Total Loss: 2.2373 | Val Recon Loss: 0.1377 | Val KL Loss: 60.3256| Val Boundary Loss: 0.0906| Val Pattern Loss: 2.0211
# Epoch 85 | Train Total Loss: 1.9556 | Recon Loss: 0.0913 | KL Loss: 70.1534 | KL Weight: 0.0001Pattern Loss: 1.7854
# Epoch 85 | Val Total Loss: 2.2338 | Val Recon Loss: 0.1428 | Val KL Loss: 61.7356| Val Boundary Loss: 0.0919| Val Pattern Loss: 2.0112
# Epoch 90 | Train Total Loss: 1.9240 | Recon Loss: 0.0883 | KL Loss: 70.4249 | KL Weight: 0.0001Pattern Loss: 1.7574
# Epoch 90 | Val Total Loss: 2.2618 | Val Recon Loss: 0.1393 | Val KL Loss: 64.0615| Val Boundary Loss: 0.0933| Val Pattern Loss: 2.0414
# Epoch 95 | Train Total Loss: 1.8711 | Recon Loss: 0.0843 | KL Loss: 70.9505 | KL Weight: 0.0001Pattern Loss: 1.7093
# Epoch 95 | Val Total Loss: 2.2515 | Val Recon Loss: 0.1368 | Val KL Loss: 60.1225| Val Boundary Loss: 0.0923| Val Pattern Loss: 2.0349
# Epoch 100 | Train Total Loss: 1.8435 | Recon Loss: 0.0816 | KL Loss: 70.7578 | KL Weight: 0.0001Pattern Loss: 1.6854
# Epoch 100 | Val Total Loss: 2.2560 | Val Recon Loss: 0.1326 | Val KL Loss: 63.1085| Val Boundary Loss: 0.0911| Val Pattern Loss: 2.0442
# Epoch 105 | Train Total Loss: 1.8250 | Recon Loss: 0.0857 | KL Loss: 70.4567 | KL Weight: 0.0001Pattern Loss: 1.6615
# Epoch 105 | Val Total Loss: 2.2542 | Val Recon Loss: 0.1387 | Val KL Loss: 61.9955| Val Boundary Loss: 0.0923| Val Pattern Loss: 2.0355
# Epoch 110 | Train Total Loss: 1.8318 | Recon Loss: 0.0846 | KL Loss: 70.2555 | KL Weight: 0.0001Pattern Loss: 1.6711
# Epoch 110 | Val Total Loss: 2.2629 | Val Recon Loss: 0.1330 | Val KL Loss: 62.2164| Val Boundary Loss: 0.0917| Val Pattern Loss: 2.0502
# Epoch 115 | Train Total Loss: 1.7715 | Recon Loss: 0.0815 | KL Loss: 71.4200 | KL Weight: 0.0001Pattern Loss: 1.6149
# Epoch 115 | Val Total Loss: 2.2969 | Val Recon Loss: 0.1328 | Val KL Loss: 62.7112| Val Boundary Loss: 0.0952| Val Pattern Loss: 2.0817
# Epoch 120 | Train Total Loss: 1.7758 | Recon Loss: 0.0800 | KL Loss: 69.5744 | KL Weight: 0.0001Pattern Loss: 1.6216
# Epoch 120 | Val Total Loss: 2.2785 | Val Recon Loss: 0.1362 | Val KL Loss: 65.0079| Val Boundary Loss: 0.0924| Val Pattern Loss: 2.0618
# Epoch 125 | Train Total Loss: 1.7096 | Recon Loss: 0.0795 | KL Loss: 72.7139 | KL Weight: 0.0001Pattern Loss: 1.5556
# Epoch 125 | Val Total Loss: 2.2686 | Val Recon Loss: 0.1358 | Val KL Loss: 63.4919| Val Boundary Loss: 0.0933| Val Pattern Loss: 2.0518
# Epoch 130 | Train Total Loss: 1.7016 | Recon Loss: 0.0783 | KL Loss: 71.5834 | KL Weight: 0.0001Pattern Loss: 1.5508
# Epoch 130 | Val Total Loss: 2.3172 | Val Recon Loss: 0.1377 | Val KL Loss: 65.2619| Val Boundary Loss: 0.0935| Val Pattern Loss: 2.0982
# Epoch 135 | Train Total Loss: 1.6766 | Recon Loss: 0.0790 | KL Loss: 72.2481 | KL Weight: 0.0001Pattern Loss: 1.5251
# Epoch 135 | Val Total Loss: 2.3018 | Val Recon Loss: 0.1441 | Val KL Loss: 65.9380| Val Boundary Loss: 0.0941| Val Pattern Loss: 2.0758
# Epoch 140 | Train Total Loss: 1.6381 | Recon Loss: 0.0746 | KL Loss: 73.1365 | KL Weight: 0.0001Pattern Loss: 1.4922
# Epoch 140 | Val Total Loss: 2.2717 | Val Recon Loss: 0.1367 | Val KL Loss: 64.6556| Val Boundary Loss: 0.0924| Val Pattern Loss: 2.0546
# Epoch 145 | Train Total Loss: 1.6588 | Recon Loss: 0.0767 | KL Loss: 72.6853 | KL Weight: 0.0001Pattern Loss: 1.5105
# Epoch 145 | Val Total Loss: 2.2820 | Val Recon Loss: 0.1421 | Val KL Loss: 64.2364| Val Boundary Loss: 0.0953| Val Pattern Loss: 2.0572
# Epoch 150 | Train Total Loss: 1.6367 | Recon Loss: 0.0743 | KL Loss: 71.7280 | KL Weight: 0.0001Pattern Loss: 1.4908
# Epoch 150 | Val Total Loss: 2.2688 | Val Recon Loss: 0.1355 | Val KL Loss: 63.0487| Val Boundary Loss: 0.0912| Val Pattern Loss: 2.0540

# %%
# Plot losses
from astro_vae_package import training
training.plot_train_val_loss(loss_hist)

# %%
torch.save(vae, 'vae_checkpoints\\vae_model_v1_full')
torch.save(vae.state_dict(), 'vae_checkpoints\\vae_model_v1_weight')

# %% [markdown]
# ### Plot Result

# %%
test_input, test_target = train_dataset[1]
test_input = test_input.to(device)
model_output = vae(test_input)
test_impute = model_output[0]
test_encode_vec = model_output[1]
test_input = test_input.cpu().detach().numpy()
test_impute = test_impute.cpu().detach().numpy()
test_target = test_target.cpu().detach().numpy()
test_diff = test_target - test_impute 
fig = plt.figure(figsize = (10, 8))
fig, axs = plt.subplots(1, 4)
vmin = -2
vmax = 5
astro_plot.subplot_linear_image(axs[0], test_input[0], np.min(test_input[0]), np.max(test_input[0]))
astro_plot.subplot_linear_image(axs[1], test_target[0], np.min(test_target[0]), np.max(test_target[0]))
astro_plot.subplot_linear_image(axs[2], test_impute[0][0], np.min(test_impute[0][0]), np.max(test_impute[0][0]))
astro_plot.subplot_linear_image(axs[3], test_diff[0][0], np.min(test_diff[0][0]), np.max(test_diff[0][0]))

# %%
disk_file_path = 'POLARIS_Exoplanet_Data\\dataset_all\\HD_129590\\2022\\20220331_1648790171\\HD_129590_2022-04-01_frames.fits'
# disk_file_path = 'plot_examples\\V351_Ori\\preprocessed\\V_V351_Ori_2021-01-21_cube_left_frames.fits'
disk_imgs = fits.getdata(disk_file_path)  #with disk
img = disk_imgs[0]
img = utils.crop_central_squared_image(img)
log_img = utils.get_log_img(img)
norm_img = utils.normalize_img(log_img)
masked_input_img = norm_img * mask_input
test_input = torch.tensor(masked_input_img, dtype=torch.float32).reshape((1, 1, 256, 256))
test_input = test_input.to(device)
model_output = vae(test_input)
test_impute = model_output[0]
test_encode_vec = model_output[1]
test_input = test_input.cpu()
test_impute = test_impute.cpu().detach().numpy()
test_diff = (norm_img - test_impute)
fig = plt.figure(figsize = (10, 8))
fig, axs = plt.subplots(1, 4)
vmin = -2
vmax = 4
astro_plot.subplot_linear_image(axs[0], masked_input_img, vmin, vmax)
astro_plot.subplot_linear_image(axs[1], norm_img, vmin, vmax)
astro_plot.subplot_linear_image(axs[2], test_impute[0][0], 0, 5)
astro_plot.subplot_linear_image(axs[3], np.exp(test_diff[0][0]), 0, 3)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(255.5), np.float64(-0.5), np.float64(255.5))

# %%
imputed_img = test_impute[0][0]
subtracted_img = np.exp(test_diff[0][0])
fits.writeto('assets\\HD_129590_2022-04-01_vae_subtracted.fits', subtracted_img, overwrite=True)
fits.writeto('assets\\HD_129590_2022-04-01_vae_imputed_bg.fits', imputed_img, overwrite=True)

# %% [markdown]
# ### Plot Result

# %%
from astro_vae_package import astro_plot
astro_plot.plot_vae_processed_image([img, img * mask_plot, imputed_img, subtracted_img])
